# %% [markdown]
# #### get all data

# %%
import pandas as pd
import os
import glob
PATH = r'C:\start\עמוס\git\nCoV2019\dataset_archive'
os.chdir(PATH)
paths = glob.glob('*outside*')
print(paths)
dfs = []
for path in paths:
    try:
        dfs.append(pd.read_csv(path))
    except UnicodeDecodeError:
        print('here')
        print(path)
# data = pd.read_csv('outside_Hubei.data.16032020T093212.csv')
# data
# data = data[['age', 'city', 'country', 'longitude', 'latitude', 'location', 'country_new']]
# data
# Out:
# ['ncov_outside_hubei_20200125 1848.csv', 'ncov_outside_hubei_20200128 0000.csv', 'ncov_outside_hubei_20200130 1911.csv', 'ncov_outside_hubei_20200201 1930.csv', 'ncov_outside_hubei_20200207 0000.csv', 'ncov_outside_hubei_20200221 1900.csv', 'outside_Hubei.data.10032020T083341.csv', 'outside_Hubei.data.12032020T011903.csv', 'outside_Hubei.data.13032020T011120.csv', 'outside_Hubei.data.14032020T011131.csv', 'outside_Hubei.data.15032020T011110.csv', 'outside_Hubei.data.16032020T011832.csv', 'outside_Hubei.data.16032020T093212.csv', 'outside_hubei_20200304 1715 GMT.csv']
# here
# ncov_outside_hubei_20200128 0000.csv
# here
# ncov_outside_hubei_20200130 1911.csv
# here
# ncov_outside_hubei_20200201 1930.csv
# here
# ncov_outside_hubei_20200207 0000.csv
# here
# ncov_outside_hubei_20200221 1900.csv
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (17,22,25,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (0,17,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (0,17,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (0,17,22,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (0,22,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# here
# outside_hubei_20200304 1715 GMT.csv

# %% [markdown]
# #### create new csv with relevant information

# %%
big_frame = pd.concat(dfs, ignore_index=True)
CSV_PATH = r'C:\start\עמוס\git\analasis\data17032020.csv'
big_frame = big_frame[['city', 'country', 'country_new', 'longitude', 'latitude', 'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation', 'symptoms']]
big_frame.to_csv(CSV_PATH, index=False)

# %% [markdown]
# #### read the csv

# %%
data = pd.read_csv(CSV_PATH)

# %% [markdown]
# #### find symptoms

# %%
symptoms = data[['symptoms']]
symptoms = symptoms[symptoms.symptoms.notnull()]
symptoms = symptoms.values.tolist()
symptoms
# Out:
# [['fever'],
#  ['fever, headache, fatigue'],
#  ['fever'],
#  ['fever'],
#  ['respiratory symptoms'],
#  ['fever'],
#  ['fever'],
#  ['fever, respiratory symptoms'],
#  ['fever, respiratory symptoms'],
#  ['fever'],
#  ['fever'],
#  ['fever, fatigue'],
#  ['fever, discomfort'],
#  ['fever, cough, headache,muscular soreness, weak'],
#  ['dizziness, cough'],
#  ['fever, cough (dry), generalized weakness, fatigue, other symptoms'],
#  ['fever, cough (dry), generalized weakness'],
#  ['fever, cough (productive), rhinorrhoea, sneezing, diarrhoea (4+ days, 7-8 times/day)'],
#  ['none'],
#  ['low fever, anhelation, pleural effusion, cough (dry), generalized weakness'],
#  ['fever, nasal congestion, sore throat, pleuritic chest pain, diarrhoea (3 days, 5-6 times/day)'],
#  ['cough'],
#  ['fever, cough'],
#  ['fever, cough'],
#  ['fever'],
#  ['fever'],
#  ['fever, cough'],
#  ['fever'],
#  ['fever, weak'],
#  ['fever, cough, muscular soreness'],
#  ['fever, cough'],
#  ['fever'],
#  ['pharyngalgia cough, muscular soreness, expectoration,chest distress'],
#  ['cough, headache'],
#  ['fever, sneeze'],
#  ['discomfort, no fever'],
#  ['cough, muscular stiffness, weak, no fever'],
#  ['fever'],
#  ['discomfort'],
#  ['fever'],
#  ['fever'],
#  ['fever, cough'],
#  ['chest distress, dyspnea'],
#  ['cough, fever, expectoration'],
#  ['fever, cough, sputum, fatigue'],
#  ['fever, chest tightness, shortness of breath'],
#  ['fever, cough'],
#  ['fever, cough'],
#  ['fever'],
#  ['fever, cough, other symotoms'],
#  ['fever, cough'],
#  ['fever, weak'],
#  ['fever, cough'],
#  ['fever, cough'],
#  ['fever, cough'],
#  ['fever, body sorrerness, cough, other symptoms'],
#  ['pharynx'],
#  ['muscular soreness'],
#  ['sore throat, cough'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever, fatigue, weakness, other symptoms'],
#  ['fever, cough, runny nose'],
#  ['fever, headache'],
#  ['fever'],
#  ['fever'],
#  ['fever, cough, dyspnea, other symptoms'],
#  ['fever'],
#  ['fever, fatigue'],
#  ['fever, chills, muscle aches, other symptoms'],
#  ['fatigue, sore throat, muscle aches'],
#  ['fever, dry cough'],
#  ['fever, cough'],
#  ['fever'],
#  ['fever, weak, sore muscle'],
#  ['fever, weak, sore muscle'],
#  ['fever, fatigue'],
#  ['fever, cough'],
#  ['fever'],
#  ['fever'],
#  ['discomfort, low fever, cough, other symptoms'],
#  ['sore throat, pneumonia'],
#  ['cough, sore throat, fever'],
#  ['fever, coughing'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['fever, cough, shortness of breath'],
#  ['cough, fever'],
#  ['fever, cough'],
#  ['fever, cold'],
#  ['fever, shortness breath, cough'],
#  ['high fever'],
#  ['chills, sore throat, headache, fever'],
#  ['fever, coughing, muscle aches'],
#  ['fever, cough'],
#  ['pneumonia'],
#  ['fever'],
#  ['fever'],
#  ['pneumonia'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['fatigue, fever, headache'],
#  ['fever'],
#  ['fever'],
#  ['respiratory symptoms'],
#  ['fever'],
#  ['fever'],
#  ['fever, respiratory symptoms'],
#  ['fever, respiratory symptoms'],
#  ['fever'],
#  ['fever'],
#  ['fatigue, fever'],
#  ['discomfort, fever'],
#  ['cough, fever, headache, muscular soreness, weak'],
#  ['cough, dizziness'],
#  ['cough, fatigue, fever, weakness'],
#  ['cough, fever, weakness'],
#  ['cough, diarrhea, fever, rhinorrhoea, sneezing'],
#  ['anhelation, cough, fever, pleural effusion, weakness'],
#  ['diarrhea, fever, nasal congestion, pleuritic chest pain, sore throat'],
#  ['cough'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever, weak'],
#  ['cough, fever, muscular soreness'],
#  ['cough, fever'],
#  ['fever'],
#  ['chest distress, cough, expectoration, muscular soreness'],
#  ['cough, headache'],
#  ['fever, sneeze'],
#  ['discomfort'],
#  ['cough, muscular stiffness, weak'],
#  ['fever'],
#  ['discomfort'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['chest distress, dyspnea'],
#  ['cough, expectoration, fever'],
#  ['cough, fatigue, fever, sputum'],
#  ['chest tightness, dyspnea, fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever, weak'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['cough, fever, soreness'],
#  ['pharynx'],
#  ['muscular soreness'],
#  ['cough, sore throat'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fatigue, fever, weakness'],
#  ['cough, fever, runny nose'],
#  ['fever, headache'],
#  ['fever'],
#  ['fever'],
#  ['cough, dyspnea, fever'],
#  ['fever'],
#  ['fatigue, fever'],
#  ['chills, fever, muscle aches, other symptoms'],
#  ['fatigue, muscle aches, sore throat'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever, sore muscle, weakness'],
#  ['fever, sore muscle, weakness'],
#  ['fatigue, fever'],
#  ['cough, fever'],
#  ['systemic weakness, runny nose, fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever, sore throat'],
#  ['fever, muscular soreness, rigor'],
#  ['chills, diarrhea, dyspnea, headache, lack of energy, muscle pain'],
#  ['cough, fever'],
#  ['cough, fatigue, fever'],
#  ['fever'],
#  ['fever, pharyngalgia'],
#  ['pneumonitis'],
#  ['pneumonia'],
#  ['pneumonia'],
#  ['fever'],
#  ['cough, discomfort, fever, other symptoms'],
#  ['flu-like symptoms'],
#  ['chills, cough, fatigue, fever'],
#  ['chills, conjunctivitis, cough, fever'],
#  ['fever, pneumonia, sore throat'],
#  ['cough, fever, sore throat'],
#  ['cough, fever'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['cough, fever, shortness of breath'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['cough, fever, shortness breath'],
#  ['fever'],
#  ['chills, fever, headache, sore throat'],
#  ['coughing, fever, muscle aches'],
#  ['cough, fever, nausea'],
#  ['cough, fever'],
#  ['cough, fever, myalgia'],
#  ['fever'],
#  ['chills, fever'],
#  ['fever, joint pain, pneumonia'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever; fatigue; dry cough'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['fever'],
#  ['fever'],
#  ['dizziness, sore limbs'],
#  ['pneumonia'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever, runny nose'],
#  ['fever'],
#  ['fever'],
#  ['pneumonia'],
#  ['pneumonia'],
#  ['pneumonitis'],
#  ['cough, fever, myalgia, rhinorrhea, sore throat'],
#  ['chills, fever, myalgias, sore throat'],
#  ['aching muscles, fever, pneumonia'],
#  ['dry cough'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['chills, cough, joint pain'],
#  ['cough, fever, pneumonia'],
#  ['fever, sore throat'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['myalgia, rhinorrhea'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['acute respiratory viral infection, fever'],
#  ['acute respiratory viral infection, fever'],
#  ['fever'],
#  ['cough'],
#  ['cough, dyspnea'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever, pharyngeal discomfort'],
#  ['chills, headache, fever'],
#  ['fever, sore throat, sputum'],
#  ['cough, fever'],
#  ['fever'],
#  ['physical discomfort'],
#  ['discomfort'],
#  ['weakness'],
#  ['fever'],
#  ['fever; cough'],
#  ['chest tightness, fever, nausea'],
#  ['respiratory symptoms'],
#  ['cough, fever'],
#  ['cough, sore throat'],
#  ['cough, fever'],
#  ['cough, fever, muscle ache'],
#  ['cough, runny nose'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['asymptomatic'],
#  ['runny nose'],
#  ['fever'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['cough, fever, sputum'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['cough, sputum'],
#  ['cough, sore throat, sputum'],
#  ['fever'],
#  ['chills, fatigue'],
#  ['cough'],
#  ['fever; dry cough; fatigue'],
#  ['lesions on chest radiographs'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['chest tightness'],
#  ['cough, fever'],
#  ['cough, fever, runny nose'],
#  ['cough, fever, runny nose'],
#  ['cough, fever, runny nose'],
#  ['fever, sore throat'],
#  ['cough, fever'],
#  ['no symptoms'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, diarrhoea, runny nose'],
#  ['cough, fever, eventually showed acute left heart failure and acute coronary syndrome'],
#  ['cough, high fever, myalgia'],
#  ['fever, myalgia'],
#  ['cough'],
#  ['cough, fever'],
#  ['cough, fever, shortness of breath'],
#  ['fatigue'],
#  ['fever;sore throat; fatigue; diarrhea'],
#  ['fever; fatigue'],
#  ['fever; sore throat;fatigue;vomiting'],
#  ['cough'],
#  ['fever'],
#  ['chest tightness, fever'],
#  ['fever, joint pain, muscle soreness'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['chills, fever'],
#  ['cough, fever'],
#  ['chest pain, nasal congestion'],
#  ['cough, muscle soreness, sweating'],
#  ['cough, fever'],
#  ['pneumonitis'],
#  ['cough, fever, shortness of breath'],
#  ['fever'],
#  ['fever'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['fever, myalgia, shortness of breath'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever, pneumonia, respiratory distress'],
#  ['fever, runny nose'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['chills, fever, runny nose, sore throat, wheezing'],
#  ['cough, respiratory problems'],
#  ['nausea, vomiting'],
#  ['fever, headache'],
#  ['fever'],
#  ['fever, full body slump'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever, cough'],
#  ['fever, cough'],
#  ['fever, dry throat, sore throat'],
#  ['fever; runny nose'],
#  ['dry throat; sore throat; fatigue'],
#  ['headache; dry mouth'],
#  ['fever; dry mouth; throat discomfort'],
#  ['fever'],
#  ['pharyngeal discomfort'],
#  ['fever'],
#  ['diarrhea'],
#  ['cough; throat discomfort'],
#  ['Pharyngeal dryness'],
#  ['cough; sputum; fever'],
#  ['fever'],
#  ['dry throat; dry cough'],
#  ['chest pain, cough'],
#  ['cough, chest tightness, dry mouth'],
#  ['cough, fever'],
#  ['fever; cough; fatigue; nausea'],
#  ['fever; cough'],
#  ['fever; fatigue'],
#  ['cough, fever'],
#  ['cough, fever, sputum'],
#  ['nausea, vomiting'],
#  ['cough, fever'],
#  ['cough, fever, sore throat'],
#  ['fever'],
#  ['cough, diarrheoa, vomiting'],
#  ['chills, cough, fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['cough, fatigue, fever'],
#  ['fever, severe pneumonia'],
#  ['eye irritation, fever'],
#  ['fever'],
#  ['cough, fever, sore throat'],
#  ['cough, fever'],
#  ['dyspnea, fever'],
#  ['cough, difficulty breathing, fever'],
#  ['fever'],
#  ['fever, headache, runny nose'],
#  ['cough, runny nose'],
#  ['transient fatigue'],
#  ['fever (38 ° C)'],
#  ['37.1 ° C, mild coughing'],
#  ['cough'],
#  ['cough'],
#  ['abdominal pain, pulmonary inflammation'],
#  ['Sore throat'],
#  ['cough'],
#  ['fever'],
#  ['feeling ill, coughing'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['anorexia, fatigue'],
#  ['abdominal pain, diarrhea, fever, general malaise'],
#  ['fever'],
#  ['cough, fever, malaise'],
#  ['fever'],
#  ['poor physical condition'],
#  ['cough, fatigue, fever'],
#  ['cough, shortness of breath'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['yes'],
#  ['fever 38.3'],
#  ['fever (39.5 ℃)'],
#  ['fever 37.7℃'],
#  ['fever 37.7℃'],
#  ['fever 37.5℃'],
#  ['anorexia'],
#  ['nausea, cough, pneumonia, fever'],
#  ['fever'],
#  ['fever 38.2 ℃, cough'],
#  ['fever (38 ° C)'],
#  ['fever 37 C'],
#  ['malaise, headache'],
#  ['fever (37 ℃), breathing difficulty'],
#  ['fever (37.5 ℃, then 38 ℃), cough, malaise'],
#  ['sore throat, Cough, fever (37 ℃)'],
#  ['difficulty breathing'],
#  ['fever'],
#  ['fever, shortness of breath, pneumonia'],
#  ['severe dyspnea'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever, cough'],
#  ['nausea'],
#  ['fever'],
#  ['fever; fatigue'],
#  ['chest tightness; fatigue'],
#  ['cough; fever'],
#  ['fever; nasal congestion; runny nose; sore throat; cough'],
#  ['fever 39.3'],
#  ['fever 38'],
#  ['fever 38'],
#  ['fever, cough'],
#  ['no respiratory symptoms, esophageal reflux'],
#  ['fever'],
#  ['fever'],
#  ['cough; sputum; fever'],
#  ['dry cough'],
#  ['cough; sore body; cold'],
#  ['fever'],
#  ['flu-like symptoms'],
#  ['acute pharyngitis'],
#  ['sore throat'],
#  ['fever, sore throat, mild cough'],
#  ['fever'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['fever, cough'],
#  ['cough'],
#  ['cough'],
#  ['low fever 37.0 ℃'],
#  ['low fever (37.4 ℃)'],
#  ['low fever (37.2 ° C); cough'],
#  ['fever (39.5 ℃), malaise'],
#  ['sore throat; fever, nasal discharge'],
#  ['fever (37.4 ° C), pneumonia'],
#  ['cough'],
#  ['fever (37.8 ℃), cough'],
#  ['fever (38-39 ° C), malaise'],
#  ['fever, cough'],
#  ['fever 38.1 ℃ Cough, malaise, anorexia'],
#  ['Discharge, cough, sore throat, chest pain'],
#  ['fever, cough, phlegm, dyspnea'],
#  ['fever, cough, phlegm, dyspnea'],
#  ['fever, cough, phlegm'],
#  ['fever 37.8 ℃ , sore throat'],
#  ['fever'],
#  ['rever, cough'],
#  ['fever 37.1 ℃ , couh'],
#  ['fever 38.3 ℃ , cough'],
#  ['malaise, fever (37 ℃); headache, toothache, pneumonia'],
#  ['Sore throat, chills'],
#  ['fever 38'],
#  ['fever 37.5 , headache, malaise'],
#  ['fever, cough, phlegm'],
#  ['Fever, cough, headache'],
#  ['fever 37.2'],
#  ['cough, malaise'],
#  ['sore throat, fever (38-39 ℃)'],
#  ['fatigue, fever (38 ℃)'],
#  ['fever (38.3 ℃)'],
#  ['vomiting, cough, fever (38.2 ℃), sore throat'],
#  ['fever (39 ° C), joint pain'],
#  ['fever (37.4 ℃), cough'],
#  ['fever (40.3 ℃), Headache, malaise, joint pain'],
#  ['fever (39.9 ℃), cough'],
#  ['fever (39.3 ℃), cough'],
#  ['cough, fever (38.3 ℃), joint pain'],
#  ['Cough, fever (38 ℃)'],
#  ['Fever (37.4 ° C), malaise, sore throa'],
#  ['cough, sore throat'],
#  ['Fever (38 ° C)'],
#  ['Fever (38.1 ° C), cough, headache.'],
#  ['no serious symptoms'],
#  ['similar to a respiratory infection'],
#  ['mild'],
#  ['chills, headache, fatigue'],
#  ['fever'],
#  ['cough, sore throat'],
#  ['cough, phlegm, fever 37 degrees'],
#  ['fever 39.0 ℃'],
#  ['fever (38.0 ℃), Fatigue, difficulty walking'],
#  ['cough'],
#  ['fever (38.0 ℃)'],
#  ['chills,  fever (38 ℃), malaise'],
#  ['Sputum, cough symptoms, fever (37 ℃), cough, breathing difficulty'],
#  ['fever (37.0 ℃), fever (38.7 ℃)'],
#  ['fever (37.5 ℃ ～ 38.0 ℃)'],
#  ['fever and cough'],
#  ['fever'],
#  ['fever (38 ° C)'],
#  ['fever (38 ° C)'],
#  ['mild'],
#  ['fever'],
#  ['sore throat'],
#  ['fever (38 ° C), fatigue'],
#  ['respiratory complaints'],
#  ['mild'],
#  ['mild'],
#  ['cough'],
#  ['acute respiratory viral infection (ARVI)'],
#  ['mild'],
#  ['fever, sneezing, coughing'],
#  ['fever, sneezing, coughing'],
#  ['fever, sneezing, coughing'],
#  ['fever, sneezing, coughing'],
#  ['fever, sneezing, coughing'],
#  ['fever, sneezing, coughing'],
#  ['mild'],
#  ['fever, chills, muscle, joint pain and cough'],
#  ['mild'],
#  ['mild'],
#  ['mild'],
#  ['mild'],
#  ['asymptomatic, afebrile'],
#  ['fever, cough'],
#  ['flu-like symptoms'],
#  ['fever'],
#  ['fever, discomfort'],
#  ['fever'],
#  ['fever'],
#  ['fever, chills'],
#  ['fever'],
#  ['fever,discmfort'],
#  ['headache'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough, fever, bone pain'],
#  ['cough'],
#  ['cough'],
#  ['cough fever'],
#  ['fever, headache, malaise, sore throat, cough'],
#  ['fever, sore throat, cough, shortness of breath'],
#  ['cough'],
#  ['cough, sore throat, body aches, fever'],
#  ['dry cough, runny nose, shortness of breath, headache'],
#  ['cough, body aches, chills'],
#  ['cough'],
#  ['fever, runny nose, body pain, diarrhea'],
#  ['cough'],
#  ['fever, cough, nasal congestion'],
#  ['fever'],
#  ['mild symptoms'],
#  ['cough, fever, shortness of breath'],
#  ['pneumonia'],
#  ['fever'],
#  ['fever'],
#  ['pneumonia'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['fatigue, fever, headache'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fatigue, fever'],
#  ['discomfort, fever'],
#  ['cough, dizziness'],
#  ['cough, fatigue, fever, weakness'],
#  ['cough, fever, weakness'],
#  ['cough, diarrhea, fever, rhinorrhoea, sneezing'],
#  ['anhelation, cough, fever, pleural effusion, weakness'],
#  ['diarrhea, fever, nasal congestion, pleuritic chest pain, sore throat'],
#  ['cough'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever, weak'],
#  ['cough, fever, muscular soreness'],
#  ['cough, fever'],
#  ['fever'],
#  ['chest distress, cough, expectoration, muscular soreness'],
#  ['cough, headache'],
#  ['fever, sneeze'],
#  ['discomfort'],
#  ['cough, muscular stiffness, weak'],
#  ['fever'],
#  ['discomfort'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['cough, expectoration, fever'],
#  ['cough, fatigue, fever, sputum'],
#  ['chest tightness, dyspnea, fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever, weak'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['pharynx'],
#  ['muscular soreness'],
#  ['cough, sore throat'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fatigue, fever, weakness'],
#  ['fever, headache'],
#  ['fever'],
#  ['fever'],
#  ['cough, dyspnea, fever'],
#  ['fever'],
#  ['fatigue, fever'],
#  ['chills, fever, muscle aches, other symptoms'],
#  ['fatigue, muscle aches, sore throat'],
#  ['fever'],
#  ['fever, sore muscle, weakness'],
#  ['fatigue, fever'],
#  ['cough, fever'],
#  ['systemic weakness, runny nose, fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever, sore throat'],
#  ['fever, muscular soreness, rigor'],
#  ['chills, diarrhea, dyspnea, headache, lack of energy, muscle pain'],
#  ['cough, fever'],
#  ['cough, fatigue, fever'],
#  ['fever'],
#  ['fever, pharyngalgia'],
#  ['pneumonitis'],
#  ['pneumonia'],
#  ['pneumonia'],
#  ['fever'],
#  ['cough, discomfort, fever, other symptoms'],
#  ['flu-like symptoms'],
#  ['chills, cough, fatigue, fever'],
#  ['chills, conjunctivitis, cough, fever'],
#  ['fever, pneumonia, sore throat'],
#  ['cough, fever, sore throat'],
#  ['cough, fever'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['cough, fever, shortness of breath'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['cough, fever, shortness breath'],
#  ['chills, fever, headache, sore throat'],
#  ['coughing, fever, muscle aches'],
#  ['cough, fever, nausea'],
#  ['cough, fever'],
#  ['cough, fever, myalgia'],
#  ['fever'],
#  ['chills, fever'],
#  ['fever, joint pain, pneumonia'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever; fatigue; dry cough'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['fever'],
#  ['fever'],
#  ['dizziness, sore limbs'],
#  ['pneumonia'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever, runny nose'],
#  ['fever'],
#  ['pneumonia'],
#  ['pneumonia'],
#  ['pneumonitis'],
#  ['cough, fever, myalgia, rhinorrhea, sore throat'],
#  ['chills, fever, myalgias, sore throat'],
#  ['aching muscles, fever, pneumonia'],
#  ['dry cough'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['chills, cough, joint pain'],
#  ['cough, fever, pneumonia'],
#  ['fever, sore throat'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['myalgia, rhinorrhea'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['acute respiratory viral infection, fever'],
#  ['acute respiratory viral infection, fever'],
#  ['fever'],
#  ['cough'],
#  ['cough, dyspnea'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever, pharyngeal discomfort'],
#  ['chills, headache, fever'],
#  ['fever, sore throat, sputum'],
#  ['cough, fever'],
#  ['fever'],
#  ['physical discomfort'],
#  ['discomfort'],
#  ['weakness'],
#  ['fever'],
#  ['fever; cough'],
#  ['chest tightness, fever, nausea'],
#  ['respiratory symptoms'],
#  ['cough, fever'],
#  ['cough, sore throat'],
#  ['cough, fever'],
#  ['cough, fever, muscle ache'],
#  ['cough, runny nose'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['asymptomatic'],
#  ['runny nose'],
#  ['fever'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['cough, fever, sputum'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['cough, sputum'],
#  ['cough, sore throat, sputum'],
#  ['fever'],
#  ['chills, fatigue'],
#  ['cough'],
#  ['fever; dry cough; fatigue'],
#  ['lesions on chest radiographs'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['chest tightness'],
#  ['cough, fever'],
#  ['cough, fever, runny nose'],
#  ['cough, fever, runny nose'],
#  ['cough, fever, runny nose'],
#  ['fever, sore throat'],
#  ['cough, fever'],
#  ['no symptoms'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, diarrhoea, runny nose'],
#  ['cough, fever, eventually showed acute left heart failure and acute coronary syndrome'],
#  ['cough, high fever, myalgia'],
#  ['fever, myalgia'],
#  ['cough'],
#  ['cough, fever'],
#  ['cough, fever, shortness of breath'],
#  ['fatigue'],
#  ['fever;sore throat; fatigue; diarrhea'],
#  ['fever; fatigue'],
#  ['fever; sore throat;fatigue;vomiting'],
#  ['cough'],
#  ['fever'],
#  ['chest tightness, fever'],
#  ['fever, joint pain, muscle soreness'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['chills, fever'],
#  ['cough, fever'],
#  ['chest pain, nasal congestion'],
#  ['cough, muscle soreness, sweating'],
#  ['cough, fever'],
#  ['pneumonitis'],
#  ['cough, fever, shortness of breath'],
#  ['fever'],
#  ['fever'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['fever, myalgia, shortness of breath'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough, fever, pneumonia, respiratory distress'],
#  ['fever, runny nose'],
#  ['cough, fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['chills, fever, runny nose, sore throat, wheezing'],
#  ['cough, respiratory problems'],
#  ['nausea, vomiting'],
#  ['fever, headache'],
#  ['fever'],
#  ['fever, full body slump'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['fever, cough'],
#  ['fever, cough'],
#  ['fever, dry throat, sore throat'],
#  ['fever; runny nose'],
#  ['dry throat; sore throat; fatigue'],
#  ['headache; dry mouth'],
#  ['fever; dry mouth; throat discomfort'],
#  ['fever'],
#  ['pharyngeal discomfort'],
#  ['fever'],
#  ['diarrhea'],
#  ['cough; throat discomfort'],
#  ['Pharyngeal dryness'],
#  ['cough; sputum; fever'],
#  ['fever'],
#  ['dry throat; dry cough'],
#  ['chest pain, cough'],
#  ['cough, chest tightness, dry mouth'],
#  ['cough, fever'],
#  ['fever; cough; fatigue; nausea'],
#  ['fever; cough'],
#  ['fever; fatigue'],
#  ['cough, fever'],
#  ['cough, fever, sputum'],
#  ['nausea, vomiting'],
#  ['cough, fever'],
#  ['cough, fever, sore throat'],
#  ['fever'],
#  ['cough, diarrheoa, vomiting'],
#  ['chills, cough, fever'],
#  ['fever'],
#  ['cough, fever'],
#  ['cough, fatigue, fever'],
#  ['fever, severe pneumonia'],
#  ['eye irritation, fever'],
#  ['fever'],
#  ['cough, fever, sore throat'],
#  ['cough, fever'],
#  ['dyspnea, fever'],
#  ['cough, difficulty breathing, fever'],
#  ['fever'],
#  ['fever, headache, runny nose'],
#  ['cough, runny nose'],
#  ['transient fatigue'],
#  ['fever (38 ° C)'],
#  ['37.1 ° C, mild coughing'],
#  ['cough'],
#  ['cough'],
#  ['abdominal pain, pulmonary inflammation'],
#  ['Sore throat'],
#  ['cough'],
#  ['fever'],
#  ['feeling ill, coughing'],
#  ['cough, fever'],
#  ['cough, fever'],
#  ['anorexia, fatigue'],
#  ['abdominal pain, diarrhea, fever, general malaise'],
#  ['fever'],
#  ...]

# %% [markdown]
# #### split to list

# %%
symptoms = [item[0].replace(';', ',') for item in symptoms]
symptoms
symptoms = [item.split(', ') for item in symptoms]
symptoms
# Out:
# [['fever'],
#  ['fever', 'headache', 'fatigue'],
#  ['fever'],
#  ['fever'],
#  ['respiratory symptoms'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'respiratory symptoms'],
#  ['fever', 'respiratory symptoms'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'fatigue'],
#  ['fever', 'discomfort'],
#  ['fever', 'cough', 'headache,muscular soreness', 'weak'],
#  ['dizziness', 'cough'],
#  ['fever', 'cough (dry)', 'generalized weakness', 'fatigue', 'other symptoms'],
#  ['fever', 'cough (dry)', 'generalized weakness'],
#  ['fever',
#   'cough (productive)',
#   'rhinorrhoea',
#   'sneezing',
#   'diarrhoea (4+ days',
#   '7-8 times/day)'],
#  ['none'],
#  ['low fever',
#   'anhelation',
#   'pleural effusion',
#   'cough (dry)',
#   'generalized weakness'],
#  ['fever',
#   'nasal congestion',
#   'sore throat',
#   'pleuritic chest pain',
#   'diarrhoea (3 days',
#   '5-6 times/day)'],
#  ['cough'],
#  ['fever', 'cough'],
#  ['fever', 'cough'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'cough'],
#  ['fever'],
#  ['fever', 'weak'],
#  ['fever', 'cough', 'muscular soreness'],
#  ['fever', 'cough'],
#  ['fever'],
#  ['pharyngalgia cough', 'muscular soreness', 'expectoration,chest distress'],
#  ['cough', 'headache'],
#  ['fever', 'sneeze'],
#  ['discomfort', 'no fever'],
#  ['cough', 'muscular stiffness', 'weak', 'no fever'],
#  ['fever'],
#  ['discomfort'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'cough'],
#  ['chest distress', 'dyspnea'],
#  ['cough', 'fever', 'expectoration'],
#  ['fever', 'cough', 'sputum', 'fatigue'],
#  ['fever', 'chest tightness', 'shortness of breath'],
#  ['fever', 'cough'],
#  ['fever', 'cough'],
#  ['fever'],
#  ['fever', 'cough', 'other symotoms'],
#  ['fever', 'cough'],
#  ['fever', 'weak'],
#  ['fever', 'cough'],
#  ['fever', 'cough'],
#  ['fever', 'cough'],
#  ['fever', 'body sorrerness', 'cough', 'other symptoms'],
#  ['pharynx'],
#  ['muscular soreness'],
#  ['sore throat', 'cough'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'fatigue', 'weakness', 'other symptoms'],
#  ['fever', 'cough', 'runny nose'],
#  ['fever', 'headache'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'cough', 'dyspnea', 'other symptoms'],
#  ['fever'],
#  ['fever', 'fatigue'],
#  ['fever', 'chills', 'muscle aches', 'other symptoms'],
#  ['fatigue', 'sore throat', 'muscle aches'],
#  ['fever', 'dry cough'],
#  ['fever', 'cough'],
#  ['fever'],
#  ['fever', 'weak', 'sore muscle'],
#  ['fever', 'weak', 'sore muscle'],
#  ['fever', 'fatigue'],
#  ['fever', 'cough'],
#  ['fever'],
#  ['fever'],
#  ['discomfort', 'low fever', 'cough', 'other symptoms'],
#  ['sore throat', 'pneumonia'],
#  ['cough', 'sore throat', 'fever'],
#  ['fever', 'coughing'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['fever', 'cough', 'shortness of breath'],
#  ['cough', 'fever'],
#  ['fever', 'cough'],
#  ['fever', 'cold'],
#  ['fever', 'shortness breath', 'cough'],
#  ['high fever'],
#  ['chills', 'sore throat', 'headache', 'fever'],
#  ['fever', 'coughing', 'muscle aches'],
#  ['fever', 'cough'],
#  ['pneumonia'],
#  ['fever'],
#  ['fever'],
#  ['pneumonia'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['fatigue', 'fever', 'headache'],
#  ['fever'],
#  ['fever'],
#  ['respiratory symptoms'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'respiratory symptoms'],
#  ['fever', 'respiratory symptoms'],
#  ['fever'],
#  ['fever'],
#  ['fatigue', 'fever'],
#  ['discomfort', 'fever'],
#  ['cough', 'fever', 'headache', 'muscular soreness', 'weak'],
#  ['cough', 'dizziness'],
#  ['cough', 'fatigue', 'fever', 'weakness'],
#  ['cough', 'fever', 'weakness'],
#  ['cough', 'diarrhea', 'fever', 'rhinorrhoea', 'sneezing'],
#  ['anhelation', 'cough', 'fever', 'pleural effusion', 'weakness'],
#  ['diarrhea',
#   'fever',
#   'nasal congestion',
#   'pleuritic chest pain',
#   'sore throat'],
#  ['cough'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever', 'weak'],
#  ['cough', 'fever', 'muscular soreness'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['chest distress', 'cough', 'expectoration', 'muscular soreness'],
#  ['cough', 'headache'],
#  ['fever', 'sneeze'],
#  ['discomfort'],
#  ['cough', 'muscular stiffness', 'weak'],
#  ['fever'],
#  ['discomfort'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['chest distress', 'dyspnea'],
#  ['cough', 'expectoration', 'fever'],
#  ['cough', 'fatigue', 'fever', 'sputum'],
#  ['chest tightness', 'dyspnea', 'fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever', 'weak'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'soreness'],
#  ['pharynx'],
#  ['muscular soreness'],
#  ['cough', 'sore throat'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fatigue', 'fever', 'weakness'],
#  ['cough', 'fever', 'runny nose'],
#  ['fever', 'headache'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'dyspnea', 'fever'],
#  ['fever'],
#  ['fatigue', 'fever'],
#  ['chills', 'fever', 'muscle aches', 'other symptoms'],
#  ['fatigue', 'muscle aches', 'sore throat'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever', 'sore muscle', 'weakness'],
#  ['fever', 'sore muscle', 'weakness'],
#  ['fatigue', 'fever'],
#  ['cough', 'fever'],
#  ['systemic weakness', 'runny nose', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'sore throat'],
#  ['fever', 'muscular soreness', 'rigor'],
#  ['chills',
#   'diarrhea',
#   'dyspnea',
#   'headache',
#   'lack of energy',
#   'muscle pain'],
#  ['cough', 'fever'],
#  ['cough', 'fatigue', 'fever'],
#  ['fever'],
#  ['fever', 'pharyngalgia'],
#  ['pneumonitis'],
#  ['pneumonia'],
#  ['pneumonia'],
#  ['fever'],
#  ['cough', 'discomfort', 'fever', 'other symptoms'],
#  ['flu-like symptoms'],
#  ['chills', 'cough', 'fatigue', 'fever'],
#  ['chills', 'conjunctivitis', 'cough', 'fever'],
#  ['fever', 'pneumonia', 'sore throat'],
#  ['cough', 'fever', 'sore throat'],
#  ['cough', 'fever'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['cough', 'fever', 'shortness of breath'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever', 'shortness breath'],
#  ['fever'],
#  ['chills', 'fever', 'headache', 'sore throat'],
#  ['coughing', 'fever', 'muscle aches'],
#  ['cough', 'fever', 'nausea'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'myalgia'],
#  ['fever'],
#  ['chills', 'fever'],
#  ['fever', 'joint pain', 'pneumonia'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever', 'fatigue', 'dry cough'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['fever'],
#  ['fever'],
#  ['dizziness', 'sore limbs'],
#  ['pneumonia'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever', 'runny nose'],
#  ['fever'],
#  ['fever'],
#  ['pneumonia'],
#  ['pneumonia'],
#  ['pneumonitis'],
#  ['cough', 'fever', 'myalgia', 'rhinorrhea', 'sore throat'],
#  ['chills', 'fever', 'myalgias', 'sore throat'],
#  ['aching muscles', 'fever', 'pneumonia'],
#  ['dry cough'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['chills', 'cough', 'joint pain'],
#  ['cough', 'fever', 'pneumonia'],
#  ['fever', 'sore throat'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['myalgia', 'rhinorrhea'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['acute respiratory viral infection', 'fever'],
#  ['acute respiratory viral infection', 'fever'],
#  ['fever'],
#  ['cough'],
#  ['cough', 'dyspnea'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever', 'pharyngeal discomfort'],
#  ['chills', 'headache', 'fever'],
#  ['fever', 'sore throat', 'sputum'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['physical discomfort'],
#  ['discomfort'],
#  ['weakness'],
#  ['fever'],
#  ['fever', 'cough'],
#  ['chest tightness', 'fever', 'nausea'],
#  ['respiratory symptoms'],
#  ['cough', 'fever'],
#  ['cough', 'sore throat'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'muscle ache'],
#  ['cough', 'runny nose'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['asymptomatic'],
#  ['runny nose'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever', 'sputum'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['cough', 'sputum'],
#  ['cough', 'sore throat', 'sputum'],
#  ['fever'],
#  ['chills', 'fatigue'],
#  ['cough'],
#  ['fever', 'dry cough', 'fatigue'],
#  ['lesions on chest radiographs'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['chest tightness'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'runny nose'],
#  ['cough', 'fever', 'runny nose'],
#  ['cough', 'fever', 'runny nose'],
#  ['fever', 'sore throat'],
#  ['cough', 'fever'],
#  ['no symptoms'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'diarrhoea', 'runny nose'],
#  ['cough',
#   'fever',
#   'eventually showed acute left heart failure and acute coronary syndrome'],
#  ['cough', 'high fever', 'myalgia'],
#  ['fever', 'myalgia'],
#  ['cough'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'shortness of breath'],
#  ['fatigue'],
#  ['fever,sore throat', 'fatigue', 'diarrhea'],
#  ['fever', 'fatigue'],
#  ['fever', 'sore throat,fatigue,vomiting'],
#  ['cough'],
#  ['fever'],
#  ['chest tightness', 'fever'],
#  ['fever', 'joint pain', 'muscle soreness'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['chills', 'fever'],
#  ['cough', 'fever'],
#  ['chest pain', 'nasal congestion'],
#  ['cough', 'muscle soreness', 'sweating'],
#  ['cough', 'fever'],
#  ['pneumonitis'],
#  ['cough', 'fever', 'shortness of breath'],
#  ['fever'],
#  ['fever'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['fever', 'myalgia', 'shortness of breath'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever', 'pneumonia', 'respiratory distress'],
#  ['fever', 'runny nose'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['chills', 'fever', 'runny nose', 'sore throat', 'wheezing'],
#  ['cough', 'respiratory problems'],
#  ['nausea', 'vomiting'],
#  ['fever', 'headache'],
#  ['fever'],
#  ['fever', 'full body slump'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever', 'cough'],
#  ['fever', 'cough'],
#  ['fever', 'dry throat', 'sore throat'],
#  ['fever', 'runny nose'],
#  ['dry throat', 'sore throat', 'fatigue'],
#  ['headache', 'dry mouth'],
#  ['fever', 'dry mouth', 'throat discomfort'],
#  ['fever'],
#  ['pharyngeal discomfort'],
#  ['fever'],
#  ['diarrhea'],
#  ['cough', 'throat discomfort'],
#  ['Pharyngeal dryness'],
#  ['cough', 'sputum', 'fever'],
#  ['fever'],
#  ['dry throat', 'dry cough'],
#  ['chest pain', 'cough'],
#  ['cough', 'chest tightness', 'dry mouth'],
#  ['cough', 'fever'],
#  ['fever', 'cough', 'fatigue', 'nausea'],
#  ['fever', 'cough'],
#  ['fever', 'fatigue'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'sputum'],
#  ['nausea', 'vomiting'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'sore throat'],
#  ['fever'],
#  ['cough', 'diarrheoa', 'vomiting'],
#  ['chills', 'cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['cough', 'fatigue', 'fever'],
#  ['fever', 'severe pneumonia'],
#  ['eye irritation', 'fever'],
#  ['fever'],
#  ['cough', 'fever', 'sore throat'],
#  ['cough', 'fever'],
#  ['dyspnea', 'fever'],
#  ['cough', 'difficulty breathing', 'fever'],
#  ['fever'],
#  ['fever', 'headache', 'runny nose'],
#  ['cough', 'runny nose'],
#  ['transient fatigue'],
#  ['fever (38 ° C)'],
#  ['37.1 ° C', 'mild coughing'],
#  ['cough'],
#  ['cough'],
#  ['abdominal pain', 'pulmonary inflammation'],
#  ['Sore throat'],
#  ['cough'],
#  ['fever'],
#  ['feeling ill', 'coughing'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['anorexia', 'fatigue'],
#  ['abdominal pain', 'diarrhea', 'fever', 'general malaise'],
#  ['fever'],
#  ['cough', 'fever', 'malaise'],
#  ['fever'],
#  ['poor physical condition'],
#  ['cough', 'fatigue', 'fever'],
#  ['cough', 'shortness of breath'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['yes'],
#  ['fever 38.3'],
#  ['fever (39.5 ℃)'],
#  ['fever 37.7℃'],
#  ['fever 37.7℃'],
#  ['fever 37.5℃'],
#  ['anorexia'],
#  ['nausea', 'cough', 'pneumonia', 'fever'],
#  ['fever'],
#  ['fever 38.2 ℃', 'cough'],
#  ['fever (38 ° C)'],
#  ['fever 37 C'],
#  ['malaise', 'headache'],
#  ['fever (37 ℃)', 'breathing difficulty'],
#  ['fever (37.5 ℃', 'then 38 ℃)', 'cough', 'malaise'],
#  ['sore throat', 'Cough', 'fever (37 ℃)'],
#  ['difficulty breathing'],
#  ['fever'],
#  ['fever', 'shortness of breath', 'pneumonia'],
#  ['severe dyspnea'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'cough'],
#  ['nausea'],
#  ['fever'],
#  ['fever', 'fatigue'],
#  ['chest tightness', 'fatigue'],
#  ['cough', 'fever'],
#  ['fever', 'nasal congestion', 'runny nose', 'sore throat', 'cough'],
#  ['fever 39.3'],
#  ['fever 38'],
#  ['fever 38'],
#  ['fever', 'cough'],
#  ['no respiratory symptoms', 'esophageal reflux'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'sputum', 'fever'],
#  ['dry cough'],
#  ['cough', 'sore body', 'cold'],
#  ['fever'],
#  ['flu-like symptoms'],
#  ['acute pharyngitis'],
#  ['sore throat'],
#  ['fever', 'sore throat', 'mild cough'],
#  ['fever'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'cough'],
#  ['cough'],
#  ['cough'],
#  ['low fever 37.0 ℃'],
#  ['low fever (37.4 ℃)'],
#  ['low fever (37.2 ° C)', 'cough'],
#  ['fever (39.5 ℃)', 'malaise'],
#  ['sore throat', 'fever', 'nasal discharge'],
#  ['fever (37.4 ° C)', 'pneumonia'],
#  ['cough'],
#  ['fever (37.8 ℃)', 'cough'],
#  ['fever (38-39 ° C)', 'malaise'],
#  ['fever', 'cough'],
#  ['fever 38.1 ℃ Cough', 'malaise', 'anorexia'],
#  ['Discharge', 'cough', 'sore throat', 'chest pain'],
#  ['fever', 'cough', 'phlegm', 'dyspnea'],
#  ['fever', 'cough', 'phlegm', 'dyspnea'],
#  ['fever', 'cough', 'phlegm'],
#  ['fever 37.8 ℃ ', 'sore throat'],
#  ['fever'],
#  ['rever', 'cough'],
#  ['fever 37.1 ℃ ', 'couh'],
#  ['fever 38.3 ℃ ', 'cough'],
#  ['malaise', 'fever (37 ℃)', 'headache', 'toothache', 'pneumonia'],
#  ['Sore throat', 'chills'],
#  ['fever 38'],
#  ['fever 37.5 ', 'headache', 'malaise'],
#  ['fever', 'cough', 'phlegm'],
#  ['Fever', 'cough', 'headache'],
#  ['fever 37.2'],
#  ['cough', 'malaise'],
#  ['sore throat', 'fever (38-39 ℃)'],
#  ['fatigue', 'fever (38 ℃)'],
#  ['fever (38.3 ℃)'],
#  ['vomiting', 'cough', 'fever (38.2 ℃)', 'sore throat'],
#  ['fever (39 ° C)', 'joint pain'],
#  ['fever (37.4 ℃)', 'cough'],
#  ['fever (40.3 ℃)', 'Headache', 'malaise', 'joint pain'],
#  ['fever (39.9 ℃)', 'cough'],
#  ['fever (39.3 ℃)', 'cough'],
#  ['cough', 'fever (38.3 ℃)', 'joint pain'],
#  ['Cough', 'fever (38 ℃)'],
#  ['Fever (37.4 ° C)', 'malaise', 'sore throa'],
#  ['cough', 'sore throat'],
#  ['Fever (38 ° C)'],
#  ['Fever (38.1 ° C)', 'cough', 'headache.'],
#  ['no serious symptoms'],
#  ['similar to a respiratory infection'],
#  ['mild'],
#  ['chills', 'headache', 'fatigue'],
#  ['fever'],
#  ['cough', 'sore throat'],
#  ['cough', 'phlegm', 'fever 37 degrees'],
#  ['fever 39.0 ℃'],
#  ['fever (38.0 ℃)', 'Fatigue', 'difficulty walking'],
#  ['cough'],
#  ['fever (38.0 ℃)'],
#  ['chills', ' fever (38 ℃)', 'malaise'],
#  ['Sputum', 'cough symptoms', 'fever (37 ℃)', 'cough', 'breathing difficulty'],
#  ['fever (37.0 ℃)', 'fever (38.7 ℃)'],
#  ['fever (37.5 ℃ ～ 38.0 ℃)'],
#  ['fever and cough'],
#  ['fever'],
#  ['fever (38 ° C)'],
#  ['fever (38 ° C)'],
#  ['mild'],
#  ['fever'],
#  ['sore throat'],
#  ['fever (38 ° C)', 'fatigue'],
#  ['respiratory complaints'],
#  ['mild'],
#  ['mild'],
#  ['cough'],
#  ['acute respiratory viral infection (ARVI)'],
#  ['mild'],
#  ['fever', 'sneezing', 'coughing'],
#  ['fever', 'sneezing', 'coughing'],
#  ['fever', 'sneezing', 'coughing'],
#  ['fever', 'sneezing', 'coughing'],
#  ['fever', 'sneezing', 'coughing'],
#  ['fever', 'sneezing', 'coughing'],
#  ['mild'],
#  ['fever', 'chills', 'muscle', 'joint pain and cough'],
#  ['mild'],
#  ['mild'],
#  ['mild'],
#  ['mild'],
#  ['asymptomatic', 'afebrile'],
#  ['fever', 'cough'],
#  ['flu-like symptoms'],
#  ['fever'],
#  ['fever', 'discomfort'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'chills'],
#  ['fever'],
#  ['fever,discmfort'],
#  ['headache'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough', 'fever', 'bone pain'],
#  ['cough'],
#  ['cough'],
#  ['cough fever'],
#  ['fever', 'headache', 'malaise', 'sore throat', 'cough'],
#  ['fever', 'sore throat', 'cough', 'shortness of breath'],
#  ['cough'],
#  ['cough', 'sore throat', 'body aches', 'fever'],
#  ['dry cough', 'runny nose', 'shortness of breath', 'headache'],
#  ['cough', 'body aches', 'chills'],
#  ['cough'],
#  ['fever', 'runny nose', 'body pain', 'diarrhea'],
#  ['cough'],
#  ['fever', 'cough', 'nasal congestion'],
#  ['fever'],
#  ['mild symptoms'],
#  ['cough', 'fever', 'shortness of breath'],
#  ['pneumonia'],
#  ['fever'],
#  ['fever'],
#  ['pneumonia'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['fatigue', 'fever', 'headache'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fatigue', 'fever'],
#  ['discomfort', 'fever'],
#  ['cough', 'dizziness'],
#  ['cough', 'fatigue', 'fever', 'weakness'],
#  ['cough', 'fever', 'weakness'],
#  ['cough', 'diarrhea', 'fever', 'rhinorrhoea', 'sneezing'],
#  ['anhelation', 'cough', 'fever', 'pleural effusion', 'weakness'],
#  ['diarrhea',
#   'fever',
#   'nasal congestion',
#   'pleuritic chest pain',
#   'sore throat'],
#  ['cough'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever', 'weak'],
#  ['cough', 'fever', 'muscular soreness'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['chest distress', 'cough', 'expectoration', 'muscular soreness'],
#  ['cough', 'headache'],
#  ['fever', 'sneeze'],
#  ['discomfort'],
#  ['cough', 'muscular stiffness', 'weak'],
#  ['fever'],
#  ['discomfort'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['cough', 'expectoration', 'fever'],
#  ['cough', 'fatigue', 'fever', 'sputum'],
#  ['chest tightness', 'dyspnea', 'fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever', 'weak'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['pharynx'],
#  ['muscular soreness'],
#  ['cough', 'sore throat'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fatigue', 'fever', 'weakness'],
#  ['fever', 'headache'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'dyspnea', 'fever'],
#  ['fever'],
#  ['fatigue', 'fever'],
#  ['chills', 'fever', 'muscle aches', 'other symptoms'],
#  ['fatigue', 'muscle aches', 'sore throat'],
#  ['fever'],
#  ['fever', 'sore muscle', 'weakness'],
#  ['fatigue', 'fever'],
#  ['cough', 'fever'],
#  ['systemic weakness', 'runny nose', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever', 'sore throat'],
#  ['fever', 'muscular soreness', 'rigor'],
#  ['chills',
#   'diarrhea',
#   'dyspnea',
#   'headache',
#   'lack of energy',
#   'muscle pain'],
#  ['cough', 'fever'],
#  ['cough', 'fatigue', 'fever'],
#  ['fever'],
#  ['fever', 'pharyngalgia'],
#  ['pneumonitis'],
#  ['pneumonia'],
#  ['pneumonia'],
#  ['fever'],
#  ['cough', 'discomfort', 'fever', 'other symptoms'],
#  ['flu-like symptoms'],
#  ['chills', 'cough', 'fatigue', 'fever'],
#  ['chills', 'conjunctivitis', 'cough', 'fever'],
#  ['fever', 'pneumonia', 'sore throat'],
#  ['cough', 'fever', 'sore throat'],
#  ['cough', 'fever'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['cough', 'fever', 'shortness of breath'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'shortness breath'],
#  ['chills', 'fever', 'headache', 'sore throat'],
#  ['coughing', 'fever', 'muscle aches'],
#  ['cough', 'fever', 'nausea'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'myalgia'],
#  ['fever'],
#  ['chills', 'fever'],
#  ['fever', 'joint pain', 'pneumonia'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever', 'fatigue', 'dry cough'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['fever'],
#  ['fever'],
#  ['dizziness', 'sore limbs'],
#  ['pneumonia'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever', 'runny nose'],
#  ['fever'],
#  ['pneumonia'],
#  ['pneumonia'],
#  ['pneumonitis'],
#  ['cough', 'fever', 'myalgia', 'rhinorrhea', 'sore throat'],
#  ['chills', 'fever', 'myalgias', 'sore throat'],
#  ['aching muscles', 'fever', 'pneumonia'],
#  ['dry cough'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['chills', 'cough', 'joint pain'],
#  ['cough', 'fever', 'pneumonia'],
#  ['fever', 'sore throat'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['myalgia', 'rhinorrhea'],
#  ['cough'],
#  ['fever'],
#  ['fever'],
#  ['acute respiratory viral infection', 'fever'],
#  ['acute respiratory viral infection', 'fever'],
#  ['fever'],
#  ['cough'],
#  ['cough', 'dyspnea'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever', 'pharyngeal discomfort'],
#  ['chills', 'headache', 'fever'],
#  ['fever', 'sore throat', 'sputum'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['physical discomfort'],
#  ['discomfort'],
#  ['weakness'],
#  ['fever'],
#  ['fever', 'cough'],
#  ['chest tightness', 'fever', 'nausea'],
#  ['respiratory symptoms'],
#  ['cough', 'fever'],
#  ['cough', 'sore throat'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'muscle ache'],
#  ['cough', 'runny nose'],
#  ['asymptomatic'],
#  ['asymptomatic'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['asymptomatic'],
#  ['runny nose'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever', 'sputum'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['cough', 'sputum'],
#  ['cough', 'sore throat', 'sputum'],
#  ['fever'],
#  ['chills', 'fatigue'],
#  ['cough'],
#  ['fever', 'dry cough', 'fatigue'],
#  ['lesions on chest radiographs'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['chest tightness'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'runny nose'],
#  ['cough', 'fever', 'runny nose'],
#  ['cough', 'fever', 'runny nose'],
#  ['fever', 'sore throat'],
#  ['cough', 'fever'],
#  ['no symptoms'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'diarrhoea', 'runny nose'],
#  ['cough',
#   'fever',
#   'eventually showed acute left heart failure and acute coronary syndrome'],
#  ['cough', 'high fever', 'myalgia'],
#  ['fever', 'myalgia'],
#  ['cough'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'shortness of breath'],
#  ['fatigue'],
#  ['fever,sore throat', 'fatigue', 'diarrhea'],
#  ['fever', 'fatigue'],
#  ['fever', 'sore throat,fatigue,vomiting'],
#  ['cough'],
#  ['fever'],
#  ['chest tightness', 'fever'],
#  ['fever', 'joint pain', 'muscle soreness'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['chills', 'fever'],
#  ['cough', 'fever'],
#  ['chest pain', 'nasal congestion'],
#  ['cough', 'muscle soreness', 'sweating'],
#  ['cough', 'fever'],
#  ['pneumonitis'],
#  ['cough', 'fever', 'shortness of breath'],
#  ['fever'],
#  ['fever'],
#  ['pneumonitis'],
#  ['pneumonitis'],
#  ['fever', 'myalgia', 'shortness of breath'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['cough', 'fever', 'pneumonia', 'respiratory distress'],
#  ['fever', 'runny nose'],
#  ['cough', 'fever'],
#  ['fever'],
#  ['fever'],
#  ['fever'],
#  ['chills', 'fever', 'runny nose', 'sore throat', 'wheezing'],
#  ['cough', 'respiratory problems'],
#  ['nausea', 'vomiting'],
#  ['fever', 'headache'],
#  ['fever'],
#  ['fever', 'full body slump'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['fever', 'cough'],
#  ['fever', 'cough'],
#  ['fever', 'dry throat', 'sore throat'],
#  ['fever', 'runny nose'],
#  ['dry throat', 'sore throat', 'fatigue'],
#  ['headache', 'dry mouth'],
#  ['fever', 'dry mouth', 'throat discomfort'],
#  ['fever'],
#  ['pharyngeal discomfort'],
#  ['fever'],
#  ['diarrhea'],
#  ['cough', 'throat discomfort'],
#  ['Pharyngeal dryness'],
#  ['cough', 'sputum', 'fever'],
#  ['fever'],
#  ['dry throat', 'dry cough'],
#  ['chest pain', 'cough'],
#  ['cough', 'chest tightness', 'dry mouth'],
#  ['cough', 'fever'],
#  ['fever', 'cough', 'fatigue', 'nausea'],
#  ['fever', 'cough'],
#  ['fever', 'fatigue'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'sputum'],
#  ['nausea', 'vomiting'],
#  ['cough', 'fever'],
#  ['cough', 'fever', 'sore throat'],
#  ['fever'],
#  ['cough', 'diarrheoa', 'vomiting'],
#  ['chills', 'cough', 'fever'],
#  ['fever'],
#  ['cough', 'fever'],
#  ['cough', 'fatigue', 'fever'],
#  ['fever', 'severe pneumonia'],
#  ['eye irritation', 'fever'],
#  ['fever'],
#  ['cough', 'fever', 'sore throat'],
#  ['cough', 'fever'],
#  ['dyspnea', 'fever'],
#  ['cough', 'difficulty breathing', 'fever'],
#  ['fever'],
#  ['fever', 'headache', 'runny nose'],
#  ['cough', 'runny nose'],
#  ['transient fatigue'],
#  ['fever (38 ° C)'],
#  ['37.1 ° C', 'mild coughing'],
#  ['cough'],
#  ['cough'],
#  ['abdominal pain', 'pulmonary inflammation'],
#  ['Sore throat'],
#  ['cough'],
#  ['fever'],
#  ['feeling ill', 'coughing'],
#  ['cough', 'fever'],
#  ['cough', 'fever'],
#  ['anorexia', 'fatigue'],
#  ['abdominal pain', 'diarrhea', 'fever', 'general malaise'],
#  ['fever'],
#  ...]

# %%
from functools import reduce
symptoms = list(reduce(lambda x, y: x+y , symptoms))
symptoms
# Out:
# ['fever',
#  'fever',
#  'headache',
#  'fatigue',
#  'fever',
#  'fever',
#  'respiratory symptoms',
#  'fever',
#  'fever',
#  'fever',
#  'respiratory symptoms',
#  'fever',
#  'respiratory symptoms',
#  'fever',
#  'fever',
#  'fever',
#  'fatigue',
#  'fever',
#  'discomfort',
#  'fever',
#  'cough',
#  'headache,muscular soreness',
#  'weak',
#  'dizziness',
#  'cough',
#  'fever',
#  'cough (dry)',
#  'generalized weakness',
#  'fatigue',
#  'other symptoms',
#  'fever',
#  'cough (dry)',
#  'generalized weakness',
#  'fever',
#  'cough (productive)',
#  'rhinorrhoea',
#  'sneezing',
#  'diarrhoea (4+ days',
#  '7-8 times/day)',
#  'none',
#  'low fever',
#  'anhelation',
#  'pleural effusion',
#  'cough (dry)',
#  'generalized weakness',
#  'fever',
#  'nasal congestion',
#  'sore throat',
#  'pleuritic chest pain',
#  'diarrhoea (3 days',
#  '5-6 times/day)',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'weak',
#  'fever',
#  'cough',
#  'muscular soreness',
#  'fever',
#  'cough',
#  'fever',
#  'pharyngalgia cough',
#  'muscular soreness',
#  'expectoration,chest distress',
#  'cough',
#  'headache',
#  'fever',
#  'sneeze',
#  'discomfort',
#  'no fever',
#  'cough',
#  'muscular stiffness',
#  'weak',
#  'no fever',
#  'fever',
#  'discomfort',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'chest distress',
#  'dyspnea',
#  'cough',
#  'fever',
#  'expectoration',
#  'fever',
#  'cough',
#  'sputum',
#  'fatigue',
#  'fever',
#  'chest tightness',
#  'shortness of breath',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'other symotoms',
#  'fever',
#  'cough',
#  'fever',
#  'weak',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'body sorrerness',
#  'cough',
#  'other symptoms',
#  'pharynx',
#  'muscular soreness',
#  'sore throat',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fatigue',
#  'weakness',
#  'other symptoms',
#  'fever',
#  'cough',
#  'runny nose',
#  'fever',
#  'headache',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'dyspnea',
#  'other symptoms',
#  'fever',
#  'fever',
#  'fatigue',
#  'fever',
#  'chills',
#  'muscle aches',
#  'other symptoms',
#  'fatigue',
#  'sore throat',
#  'muscle aches',
#  'fever',
#  'dry cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'weak',
#  'sore muscle',
#  'fever',
#  'weak',
#  'sore muscle',
#  'fever',
#  'fatigue',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'discomfort',
#  'low fever',
#  'cough',
#  'other symptoms',
#  'sore throat',
#  'pneumonia',
#  'cough',
#  'sore throat',
#  'fever',
#  'fever',
#  'coughing',
#  'asymptomatic',
#  'asymptomatic',
#  'asymptomatic',
#  'fever',
#  'cough',
#  'shortness of breath',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'cold',
#  'fever',
#  'shortness breath',
#  'cough',
#  'high fever',
#  'chills',
#  'sore throat',
#  'headache',
#  'fever',
#  'fever',
#  'coughing',
#  'muscle aches',
#  'fever',
#  'cough',
#  'pneumonia',
#  'fever',
#  'fever',
#  'pneumonia',
#  'cough',
#  'fever',
#  'fever',
#  'fatigue',
#  'fever',
#  'headache',
#  'fever',
#  'fever',
#  'respiratory symptoms',
#  'fever',
#  'fever',
#  'fever',
#  'respiratory symptoms',
#  'fever',
#  'respiratory symptoms',
#  'fever',
#  'fever',
#  'fatigue',
#  'fever',
#  'discomfort',
#  'fever',
#  'cough',
#  'fever',
#  'headache',
#  'muscular soreness',
#  'weak',
#  'cough',
#  'dizziness',
#  'cough',
#  'fatigue',
#  'fever',
#  'weakness',
#  'cough',
#  'fever',
#  'weakness',
#  'cough',
#  'diarrhea',
#  'fever',
#  'rhinorrhoea',
#  'sneezing',
#  'anhelation',
#  'cough',
#  'fever',
#  'pleural effusion',
#  'weakness',
#  'diarrhea',
#  'fever',
#  'nasal congestion',
#  'pleuritic chest pain',
#  'sore throat',
#  'cough',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'weak',
#  'cough',
#  'fever',
#  'muscular soreness',
#  'cough',
#  'fever',
#  'fever',
#  'chest distress',
#  'cough',
#  'expectoration',
#  'muscular soreness',
#  'cough',
#  'headache',
#  'fever',
#  'sneeze',
#  'discomfort',
#  'cough',
#  'muscular stiffness',
#  'weak',
#  'fever',
#  'discomfort',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'chest distress',
#  'dyspnea',
#  'cough',
#  'expectoration',
#  'fever',
#  'cough',
#  'fatigue',
#  'fever',
#  'sputum',
#  'chest tightness',
#  'dyspnea',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'weak',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'soreness',
#  'pharynx',
#  'muscular soreness',
#  'cough',
#  'sore throat',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fatigue',
#  'fever',
#  'weakness',
#  'cough',
#  'fever',
#  'runny nose',
#  'fever',
#  'headache',
#  'fever',
#  'fever',
#  'cough',
#  'dyspnea',
#  'fever',
#  'fever',
#  'fatigue',
#  'fever',
#  'chills',
#  'fever',
#  'muscle aches',
#  'other symptoms',
#  'fatigue',
#  'muscle aches',
#  'sore throat',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'sore muscle',
#  'weakness',
#  'fever',
#  'sore muscle',
#  'weakness',
#  'fatigue',
#  'fever',
#  'cough',
#  'fever',
#  'systemic weakness',
#  'runny nose',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'sore throat',
#  'fever',
#  'muscular soreness',
#  'rigor',
#  'chills',
#  'diarrhea',
#  'dyspnea',
#  'headache',
#  'lack of energy',
#  'muscle pain',
#  'cough',
#  'fever',
#  'cough',
#  'fatigue',
#  'fever',
#  'fever',
#  'fever',
#  'pharyngalgia',
#  'pneumonitis',
#  'pneumonia',
#  'pneumonia',
#  'fever',
#  'cough',
#  'discomfort',
#  'fever',
#  'other symptoms',
#  'flu-like symptoms',
#  'chills',
#  'cough',
#  'fatigue',
#  'fever',
#  'chills',
#  'conjunctivitis',
#  'cough',
#  'fever',
#  'fever',
#  'pneumonia',
#  'sore throat',
#  'cough',
#  'fever',
#  'sore throat',
#  'cough',
#  'fever',
#  'asymptomatic',
#  'asymptomatic',
#  'asymptomatic',
#  'cough',
#  'fever',
#  'shortness of breath',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'shortness breath',
#  'fever',
#  'chills',
#  'fever',
#  'headache',
#  'sore throat',
#  'coughing',
#  'fever',
#  'muscle aches',
#  'cough',
#  'fever',
#  'nausea',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'myalgia',
#  'fever',
#  'chills',
#  'fever',
#  'fever',
#  'joint pain',
#  'pneumonia',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'fatigue',
#  'dry cough',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'fever',
#  'fever',
#  'dizziness',
#  'sore limbs',
#  'pneumonia',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'runny nose',
#  'fever',
#  'fever',
#  'pneumonia',
#  'pneumonia',
#  'pneumonitis',
#  'cough',
#  'fever',
#  'myalgia',
#  'rhinorrhea',
#  'sore throat',
#  'chills',
#  'fever',
#  'myalgias',
#  'sore throat',
#  'aching muscles',
#  'fever',
#  'pneumonia',
#  'dry cough',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'chills',
#  'cough',
#  'joint pain',
#  'cough',
#  'fever',
#  'pneumonia',
#  'fever',
#  'sore throat',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'pneumonitis',
#  'myalgia',
#  'rhinorrhea',
#  'cough',
#  'fever',
#  'fever',
#  'acute respiratory viral infection',
#  'fever',
#  'acute respiratory viral infection',
#  'fever',
#  'fever',
#  'cough',
#  'cough',
#  'dyspnea',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'pharyngeal discomfort',
#  'chills',
#  'headache',
#  'fever',
#  'fever',
#  'sore throat',
#  'sputum',
#  'cough',
#  'fever',
#  'fever',
#  'physical discomfort',
#  'discomfort',
#  'weakness',
#  'fever',
#  'fever',
#  'cough',
#  'chest tightness',
#  'fever',
#  'nausea',
#  'respiratory symptoms',
#  'cough',
#  'fever',
#  'cough',
#  'sore throat',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'muscle ache',
#  'cough',
#  'runny nose',
#  'asymptomatic',
#  'asymptomatic',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'asymptomatic',
#  'runny nose',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'sputum',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'sputum',
#  'cough',
#  'sore throat',
#  'sputum',
#  'fever',
#  'chills',
#  'fatigue',
#  'cough',
#  'fever',
#  'dry cough',
#  'fatigue',
#  'lesions on chest radiographs',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'chest tightness',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'runny nose',
#  'cough',
#  'fever',
#  'runny nose',
#  'cough',
#  'fever',
#  'runny nose',
#  'fever',
#  'sore throat',
#  'cough',
#  'fever',
#  'no symptoms',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'diarrhoea',
#  'runny nose',
#  'cough',
#  'fever',
#  'eventually showed acute left heart failure and acute coronary syndrome',
#  'cough',
#  'high fever',
#  'myalgia',
#  'fever',
#  'myalgia',
#  'cough',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'shortness of breath',
#  'fatigue',
#  'fever,sore throat',
#  'fatigue',
#  'diarrhea',
#  'fever',
#  'fatigue',
#  'fever',
#  'sore throat,fatigue,vomiting',
#  'cough',
#  'fever',
#  'chest tightness',
#  'fever',
#  'fever',
#  'joint pain',
#  'muscle soreness',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'chills',
#  'fever',
#  'cough',
#  'fever',
#  'chest pain',
#  'nasal congestion',
#  'cough',
#  'muscle soreness',
#  'sweating',
#  'cough',
#  'fever',
#  'pneumonitis',
#  'cough',
#  'fever',
#  'shortness of breath',
#  'fever',
#  'fever',
#  'pneumonitis',
#  'pneumonitis',
#  'fever',
#  'myalgia',
#  'shortness of breath',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'pneumonia',
#  'respiratory distress',
#  'fever',
#  'runny nose',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'chills',
#  'fever',
#  'runny nose',
#  'sore throat',
#  'wheezing',
#  'cough',
#  'respiratory problems',
#  'nausea',
#  'vomiting',
#  'fever',
#  'headache',
#  'fever',
#  'fever',
#  'full body slump',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'dry throat',
#  'sore throat',
#  'fever',
#  'runny nose',
#  'dry throat',
#  'sore throat',
#  'fatigue',
#  'headache',
#  'dry mouth',
#  'fever',
#  'dry mouth',
#  'throat discomfort',
#  'fever',
#  'pharyngeal discomfort',
#  'fever',
#  'diarrhea',
#  'cough',
#  'throat discomfort',
#  'Pharyngeal dryness',
#  'cough',
#  'sputum',
#  'fever',
#  'fever',
#  'dry throat',
#  'dry cough',
#  'chest pain',
#  'cough',
#  'cough',
#  'chest tightness',
#  'dry mouth',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'fatigue',
#  'nausea',
#  'fever',
#  'cough',
#  'fever',
#  'fatigue',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'sputum',
#  'nausea',
#  'vomiting',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'sore throat',
#  'fever',
#  'cough',
#  'diarrheoa',
#  'vomiting',
#  'chills',
#  'cough',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'cough',
#  'fatigue',
#  'fever',
#  'fever',
#  'severe pneumonia',
#  'eye irritation',
#  'fever',
#  'fever',
#  'cough',
#  'fever',
#  'sore throat',
#  'cough',
#  'fever',
#  'dyspnea',
#  'fever',
#  'cough',
#  'difficulty breathing',
#  'fever',
#  'fever',
#  'fever',
#  'headache',
#  'runny nose',
#  'cough',
#  'runny nose',
#  'transient fatigue',
#  'fever (38 ° C)',
#  '37.1 ° C',
#  'mild coughing',
#  'cough',
#  'cough',
#  'abdominal pain',
#  'pulmonary inflammation',
#  'Sore throat',
#  'cough',
#  'fever',
#  'feeling ill',
#  'coughing',
#  'cough',
#  'fever',
#  'cough',
#  'fever',
#  'anorexia',
#  'fatigue',
#  'abdominal pain',
#  'diarrhea',
#  'fever',
#  'general malaise',
#  'fever',
#  'cough',
#  'fever',
#  'malaise',
#  'fever',
#  'poor physical condition',
#  'cough',
#  'fatigue',
#  'fever',
#  'cough',
#  'shortness of breath',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'yes',
#  'fever 38.3',
#  'fever (39.5 ℃)',
#  'fever 37.7℃',
#  'fever 37.7℃',
#  'fever 37.5℃',
#  'anorexia',
#  'nausea',
#  'cough',
#  'pneumonia',
#  'fever',
#  'fever',
#  'fever 38.2 ℃',
#  'cough',
#  'fever (38 ° C)',
#  'fever 37 C',
#  'malaise',
#  'headache',
#  'fever (37 ℃)',
#  'breathing difficulty',
#  'fever (37.5 ℃',
#  'then 38 ℃)',
#  'cough',
#  'malaise',
#  'sore throat',
#  'Cough',
#  'fever (37 ℃)',
#  'difficulty breathing',
#  'fever',
#  'fever',
#  'shortness of breath',
#  'pneumonia',
#  'severe dyspnea',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'nausea',
#  'fever',
#  'fever',
#  'fatigue',
#  'chest tightness',
#  'fatigue',
#  'cough',
#  'fever',
#  'fever',
#  'nasal congestion',
#  'runny nose',
#  'sore throat',
#  'cough',
#  'fever 39.3',
#  'fever 38',
#  'fever 38',
#  'fever',
#  'cough',
#  'no respiratory symptoms',
#  'esophageal reflux',
#  'fever',
#  'fever',
#  'cough',
#  'sputum',
#  'fever',
#  'dry cough',
#  'cough',
#  'sore body',
#  'cold',
#  'fever',
#  'flu-like symptoms',
#  'acute pharyngitis',
#  'sore throat',
#  'fever',
#  'sore throat',
#  'mild cough',
#  'fever',
#  'cough',
#  'fever',
#  'fever',
#  'fever',
#  'cough',
#  'cough',
#  'cough',
#  'low fever 37.0 ℃',
#  'low fever (37.4 ℃)',
#  'low fever (37.2 ° C)',
#  'cough',
#  'fever (39.5 ℃)',
#  'malaise',
#  'sore throat',
#  'fever',
#  'nasal discharge',
#  'fever (37.4 ° C)',
#  'pneumonia',
#  'cough',
#  'fever (37.8 ℃)',
#  'cough',
#  'fever (38-39 ° C)',
#  'malaise',
#  'fever',
#  'cough',
#  'fever 38.1 ℃ Cough',
#  'malaise',
#  'anorexia',
#  'Discharge',
#  'cough',
#  'sore throat',
#  'chest pain',
#  ...]

# %% [markdown]
# #### count the different symptoms

# %%
import collections
symptoms_mifkad = collections.Counter(symptoms)
common_symptoms = symptoms_mifkad.most_common()
common_symptoms
# Out:
# [('fever', 2373),
#  ('cough', 1361),
#  ('sore throat', 264),
#  ('fatigue', 195),
#  ('chills', 142),
#  ('pneumonitis', 133),
#  ('headache', 129),
#  ('runny nose', 114),
#  ('pneumonia', 114),
#  ('malaise', 91),
#  ('mild', 76),
#  ('shortness of breath', 72),
#  ('bone pain', 60),
#  ('coughing', 58),
#  ('sputum', 57),
#  ('nausea', 55),
#  ('dry cough', 54),
#  ('dyspnea', 53),
#  ('asymptomatic', 52),
#  ('sneezing', 51),
#  ('diarrhea', 50),
#  ('weakness', 44),
#  ('chest tightness', 43),
#  ('joint pain', 43),
#  ('phlegm', 43),
#  ('myalgia', 42),
#  ('discomfort', 40),
#  ('muscular soreness', 32),
#  ('nasal congestion', 29),
#  ('fever (38 ° C)', 29),
#  ('weak', 28),
#  ('muscle aches', 28),
#  ('vomiting', 28),
#  ('fever (37 ℃)', 28),
#  ('fever 38', 22),
#  ('flu-like symptoms', 21),
#  ('chest pain', 21),
#  ('dry throat', 21),
#  ('dry mouth', 21),
#  ('anorexia', 21),
#  ('other symptoms', 20),
#  ('abdominal pain', 18),
#  ('body aches', 18),
#  ('Cough', 16),
#  ('dizziness', 15),
#  ('expectoration', 15),
#  ('breathing difficulty', 15),
#  ('fever (38 ℃)', 15),
#  ('rhinorrhea', 14),
#  ('acute respiratory viral infection', 14),
#  ('pharyngeal discomfort', 14),
#  ('muscle soreness', 14),
#  ('throat discomfort', 14),
#  ('difficulty breathing', 14),
#  ('Sore throat', 14),
#  ('fever (39.5 ℃)', 14),
#  ('fever 37.7℃', 14),
#  ('fever (38.3 ℃)', 14),
#  ('fever (38.0 ℃)', 14),
#  ('respiratory symptoms', 13),
#  ('Fever', 13),
#  ('sore muscle', 10),
#  ('general malaise', 10),
#  ('chest distress', 9),
#  ('09.03.2020', 9),
#  ('rhinorrhoea', 8),
#  ('anhelation', 8),
#  ('pleural effusion', 8),
#  ('pleuritic chest pain', 8),
#  ('sneeze', 8),
#  ('muscular stiffness', 8),
#  ('pharynx', 8),
#  ('cold', 8),
#  ('shortness breath', 8),
#  ('high fever', 8),
#  ('nasal discharge', 8),
#  ('fever (37.8 ℃)', 8),
#  ('fever 37.2', 8),
#  ('13.02.2020', 8),
#  ('systemic weakness', 7),
#  ('rigor', 7),
#  ('lack of energy', 7),
#  ('muscle pain', 7),
#  ('pharyngalgia', 7),
#  ('conjunctivitis', 7),
#  ('sore limbs', 7),
#  ('myalgias', 7),
#  ('aching muscles', 7),
#  ('physical discomfort', 7),
#  ('muscle ache', 7),
#  ('lesions on chest radiographs', 7),
#  ('no symptoms', 7),
#  ('diarrhoea', 7),
#  ('eventually showed acute left heart failure and acute coronary syndrome', 7),
#  ('fever,sore throat', 7),
#  ('sore throat,fatigue,vomiting', 7),
#  ('sweating', 7),
#  ('respiratory distress', 7),
#  ('wheezing', 7),
#  ('respiratory problems', 7),
#  ('full body slump', 7),
#  ('Pharyngeal dryness', 7),
#  ('diarrheoa', 7),
#  ('severe pneumonia', 7),
#  ('eye irritation', 7),
#  ('transient fatigue', 7),
#  ('37.1 ° C', 7),
#  ('mild coughing', 7),
#  ('pulmonary inflammation', 7),
#  ('feeling ill', 7),
#  ('poor physical condition', 7),
#  ('yes', 7),
#  ('fever 38.3', 7),
#  ('fever 37.5℃', 7),
#  ('fever 38.2 ℃', 7),
#  ('fever 37 C', 7),
#  ('fever (37.5 ℃', 7),
#  ('then 38 ℃)', 7),
#  ('severe dyspnea', 7),
#  ('fever 39.3', 7),
#  ('no respiratory symptoms', 7),
#  ('esophageal reflux', 7),
#  ('sore body', 7),
#  ('acute pharyngitis', 7),
#  ('mild cough', 7),
#  ('low fever 37.0 ℃', 7),
#  ('low fever (37.4 ℃)', 7),
#  ('low fever (37.2 ° C)', 7),
#  ('fever (37.4 ° C)', 7),
#  ('fever (38-39 ° C)', 7),
#  ('fever 38.1 ℃ Cough', 7),
#  ('Discharge', 7),
#  ('fever 37.8 ℃ ', 7),
#  ('rever', 7),
#  ('fever 37.1 ℃ ', 7),
#  ('couh', 7),
#  ('fever 38.3 ℃ ', 7),
#  ('toothache', 7),
#  ('fever (38-39 ℃)', 7),
#  ('fever (38.2 ℃)', 7),
#  ('fever (39 ° C)', 7),
#  ('fever (37.4 ℃)', 7),
#  ('fever (40.3 ℃)', 7),
#  ('Headache', 7),
#  ('fever (39.9 ℃)', 7),
#  ('fever (39.3 ℃)', 7),
#  ('Fever (37.4 ° C)', 7),
#  ('sore throa', 7),
#  ('Fever (38 ° C)', 7),
#  ('Fever (38.1 ° C)', 7),
#  ('headache.', 7),
#  ('no serious symptoms', 7),
#  ('similar to a respiratory infection', 7),
#  ('fever 37 degrees', 7),
#  ('fever 39.0 ℃', 7),
#  ('Fatigue', 7),
#  ('difficulty walking', 7),
#  (' fever (38 ℃)', 7),
#  ('Sputum', 7),
#  ('cough symptoms', 7),
#  ('fever (37.0 ℃)', 7),
#  ('fever (38.7 ℃)', 7),
#  ('fever (37.5 ℃ ～ 38.0 ℃)', 7),
#  ('fever and cough', 7),
#  ('respiratory complaints', 7),
#  ('acute respiratory viral infection (ARVI)', 7),
#  ('muscle', 7),
#  ('joint pain and cough', 7),
#  ('afebrile', 7),
#  ('body pain', 7),
#  ('mild symptoms', 7),
#  ('cough fever', 6),
#  ('lethargy', 6),
#  ('digestive discomfort', 6),
#  ('aggressive pulmonary symptomatology', 6),
#  ('fever,discmfort', 5),
#  ('cough (dry)', 3),
#  ('generalized weakness', 3),
#  ('11.03.2020', 3),
#  ('low fever', 2),
#  ('no fever', 2),
#  ('headache,muscular soreness', 1),
#  ('cough (productive)', 1),
#  ('diarrhoea (4+ days', 1),
#  ('7-8 times/day)', 1),
#  ('none', 1),
#  ('diarrhoea (3 days', 1),
#  ('5-6 times/day)', 1),
#  ('pharyngalgia cough', 1),
#  ('expectoration,chest distress', 1),
#  ('other symotoms', 1),
#  ('body sorrerness', 1),
#  ('soreness', 1),
#  ('fever 37.5 ', 1),
#  ('12.03.2020', 1),
#  ('fever (37.2 ° C)', 1),
#  ('joint muscle pain', 1),
#  ('and malaise', 1),
#  ('influenza', 1),
#  ('vomiting.', 1),
#  ('fever 37.8 ° C Dyspnea with pneumonia', 1),
#  ('fever (38.0 ° C)', 1),
#  ('fever (38.6 ℃)', 1),
#  ('difficuty breathing', 1),
#  ('fever (38.9℃)', 1),
#  ('fever (38.2℃)', 1),
#  ('backache', 1),
#  ('fever  (37.0-5 ℃)', 1),
#  ('fever  (37.2 ℃)', 1),
#  ('fever (38.5 ℃)', 1),
#  ('mausea', 1),
#  ('mile cough', 1),
#  ('minor fatigue', 1),
#  ('fever 37.5', 1),
#  ('cough Difficulty breathing', 1),
#  ('general pain', 1),
#  ('fever 38.0', 1),
#  ('fever 40.0', 1)]
